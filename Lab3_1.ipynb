# %%
#pandas is a library used for data analysis and manipulation
import pandas as pd

#Loading exclusively the sheet that is required.
df = pd.read_csv('embeddingsdata_copy.csv')

print("\nThe loaded data is as follows:\n")
print(df)
#It is observed that the whole table is not printed, and the number of rows and columns within the dataset is printed
# Out:
# The loaded data is as follows:
#
#       embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0    0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1   -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2    0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3    0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4    0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.019743 -0.071799  0.022546  0.049042 -0.005767 -0.016275 -0.037731
# 896  0.000186 -0.027604  0.010623  0.038237 -0.026675  0.020215 -0.040816
# 897  0.018066 -0.032152  0.039794  0.047608  0.003898  0.024092 -0.056508
# 898 -0.003492 -0.022739  0.021777  0.044054 -0.005621  0.013863 -0.079196
# 899  0.013689 -0.037855  0.039763  0.035750  0.004115  0.005637 -0.050556
#
# ...

# %%
'''
A3. Take any two feature vectors from your dataset. Calculate the Minkwoski distance with r from 1
to 10. Make a plot of the distance and observe the nature of this graph
'''
'''The Minkowski distance is a flexible metric commonly used in clustering, classification, and machine learning algorithms
    When r=1r=1, it becomes the Manhattan distance, also known as the L1 norm or taxicab distance. It measures the sum of the absolute differences between the coordinates of the points, giving a "block" distance.

    When r=2r=2, it becomes the Euclidean distance, which measures the straight-line distance between the points in Euclidean space.

    As rr approaches infinity (r→∞r→∞), the Minkowski distance becomes the Chebyshev distance. It measures the maximum absolute difference between any coordinate of the points.
'''
import numpy as np
import matplotlib.pyplot as plt

# Define your two feature vectors (replace these with your actual data)
vector1 = np.array([0.009624697, -0.007534713, 0.022407679, 0.019676726, 0.0176783, 0.020490186, -0.001626733, 0.017095815, 0.016423039, 0.003272215, -0.006775622, 0.003002599, 0.014168609, -0.00100205, 0.02155927, 0.007590317, 0.013016738, -0.002454198, 0.004454556, 0.030535258, 0.0157698, 0.02424321, 0.042638492, 0.012378418, 0.006486579, 0.026036037, 0.001464179, 0.005533471, 0.012665072, 0.019026639, 0.031132834, 0.026356058, 0.002694097, 0.003373266, 0.019623978, 0.01525427, 0.023528464, 0.018155662, 0.004446905, 0.034327902, 0.017064674, 0.010528078, 0.007613701, -0.001533787, 0.005390956, 0.020713152, 0.00406714, 0.008387806, 0.003579948, 0.017891964, 0.005316185, 0.023818534, 0.023816265, 0.020520324, 0.035503108, -0.004102687, 0.008478904, 0.001520448, 0.026256835, 0.02019655, 0.013716606, 0.026534926, -0.002619437, 0.015130441, 0.034713667, -0.008996385, -0.00200571, 0.011942029, 0.00383152])  # Replace ... with the remaining values
vector2 = np.array([-0.029216224, -0.039844163, -0.030839974, -0.034055371, -0.030322548, -0.033387568, -0.030681809, -0.038767461, -0.028484207, -0.020666257, -0.030313252, -0.034048021, -0.019782986, -0.02904349, -0.015028024, -0.033201355, -0.040595029, -0.031319574, -0.020436302, -0.020893399, -0.039677389, -0.023950506, -0.020796753, -0.00282401, -0.009418397, -0.034857426, -0.028361522, -0.018680319, -0.038957588, -0.02415435, -0.023388915, -0.03110891, -0.042968474, -0.021220218, -0.024153851, -0.025098812, -0.028582618, -0.032617312, -0.039490387, -0.020693123, -0.017073832, -0.027666161, -0.030362327, -0.017946715, -0.02991315, -0.024929337, -0.027642002, -0.037147302, -0.028209237, -0.035859946, -0.013126941, -0.016720591, -0.041745316, -0.013054741, -0.016432134, -0.022637105, -0.019108687, -0.032192305, -0.033490442, -0.039245222, -0.021507304, -0.017956622, -0.017073002, -0.0250571, -0.024369204, -0.026673958, -0.045342721, -0.018237915, -0.053947262])
# Create a list to store distances for different values of r
distances = []

# Calculate Minkowski distances for r from 1 to 10
for r in range(1, 11):
    distance = np.power(np.sum(np.power(np.abs(vector1 - vector2), r)), 1/r)
    distances.append(distance)

# Plot the distances
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), distances, marker='o', linestyle='-')
plt.title('Minkowski Distance vs. r')
plt.xlabel('r')
plt.ylabel('Minkowski Distance')
plt.grid(True)
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Assuming you have a feature matrix X and corresponding labels y

# Split the dataset into a training set (70%) and a testing set (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# The 'test_size' parameter determines the size of the testing set, you can adjust it as needed.
# 'random_state' is used to ensure reproducibility; you can choose any integer value or leave it out.

# Now you can use X_train and y_train for training your model
# and X_test and y_test for testing your model.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       2 from sklearn.model_selection import train_test_split
#       4 # Assuming you have a feature matrix X and corresponding labels y
#       5
#       6 # Split the dataset into a training set (70%) and a testing set (30%)
# ----> 7 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#       9 # The 'test_size' parameter determines the size of the testing set, you can adjust it as needed.
#      10 # 'random_state' is used to ensure reproducibility; you can choose any integer value or leave it out.
#      11
#      12 # Now you can use X_train and y_train for training your model
#      13 # and X_test and y_test for testing your model.
#
# NameError: name 'X' is not defined
